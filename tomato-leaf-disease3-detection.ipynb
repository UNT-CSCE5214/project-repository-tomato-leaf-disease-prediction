# %% [markdown]
# # Fitting in the Model

# %%
# fit the model
# Run the cell. It will take some time to execute
r = model.fit(
  training_set,
  validation_data=test_set,
  epochs=5,
  validation_steps=len(test_set)
)
# Out:
# Epoch 1/5
# 574/574 [==============================] - 349s 591ms/step - loss: 4.5910 - accuracy: 0.5856 - val_loss: 2.0723 - val_accuracy: 0.7668
# Epoch 2/5
# 574/574 [==============================] - 228s 398ms/step - loss: 2.0654 - accuracy: 0.7820 - val_loss: 3.4844 - val_accuracy: 0.7424
# Epoch 3/5
# 574/574 [==============================] - 228s 398ms/step - loss: 1.9703 - accuracy: 0.8197 - val_loss: 3.6746 - val_accuracy: 0.7459
# Epoch 4/5
# 574/574 [==============================] - 230s 400ms/step - loss: 1.7310 - accuracy: 0.8494 - val_loss: 2.1903 - val_accuracy: 0.8323
# Epoch 5/5
# 574/574 [==============================] - 232s 403ms/step - loss: 1.6688 - accuracy: 0.8620 - val_loss: 1.8811 - val_accuracy: 0.8580
